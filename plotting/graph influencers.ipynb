# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
### read in data
fileName = '../sentiment_analysis/textblob_data/influencers.txt'    
influencers = pd.read_csv(fileName, sep=" ",header=None)
influencers.columns = ['Creator','Positive','Negative']
c = list(influencers['Creator'])
c = [i.split('.')[0] for i in c]
influencers['Creator'] = c

influencers.set_index('Creator', inplace=True)

#Normalize Scores
influencers['Negative'] = abs(influencers['Negative'])
influencers['Normalized Positive'] = influencers['Positive']/(influencers['Positive']+influencers['Negative'])*100
influencers['Normalized Negative'] = influencers['Negative']/(influencers['Positive']+influencers['Negative'])*100

# %%
influencers['Gender'] = ['Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male','Male', 'Female', 'Female']

# %%
influencers['Category'] = ['Influencers']*len(influencers)

# %%
influencers
# Out:
#                        Positive     Negative  Normalized Positive  \
# Creator
# jacksfilms          2702.978057  1066.091843            71.714723
# rhettandlink2       5649.296625  1204.402695            82.426969
# markiplierGAME        85.689644    49.249242            63.502558
# IISuperwomanII      5850.576387   743.504455            88.724669
# TheFineBros         9856.973009  3120.590987            75.953954
# MrBeast6000         5508.615069  1182.230461            82.330627
# mylifeaseva         4084.641140   650.648712            86.259580
# smosh               3247.089159   758.006625            81.073945
# kandeejohnson       8790.812156   748.947824            92.149196
# nigahiga            4237.346386   867.608486            83.004581
# missglamorazzi      2386.047400   312.159556            88.430852
# tyleroakley         4118.327530   415.970214            90.826138
# HolaSoyGerman        335.967478   237.221875            58.613698
# ...

# %%
#read in data
fileName2 = '../sentiment_analysis/textblob_data/cooking.txt'    
cooking = pd.read_csv(fileName2, sep=", ",header=None)
cooking.columns = ['Creator','File','Positive','Negative','Gender','Country']
c = list(cooking['File'])
c = [i.split('.')[0] for i in c]
cooking['Creator'] = c
cooking.set_index('Creator', inplace=True)

#Normalize Scores
cooking['Negative'] = abs(cooking['Negative'])
cooking['Normalized Positive'] = cooking['Positive']/(cooking['Positive']+cooking['Negative'])*100
cooking['Normalized Negative'] = cooking['Negative']/(cooking['Positive']+cooking['Negative'])*100
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
cooking.drop(columns=['File', 'Country'], inplace=True)

# %%
cooking['Category'] = ['Cooking']*len(cooking)

# %%
cooking
# Out:
#                                         Positive     Negative  Gender  \
# Creator
# ByronTalbott                         1589.901485   129.886387    Male
# donalskehan                          1072.572006    78.765463    Male
# PL2EC7F45DBD9D9B1A                  22257.240115  4053.419950  Female
# LauraVitalesKitchen                  2875.792363   163.268098  Female
# bgfilms                              7814.826232  1664.841656    Male
# cookingwithdog                       5638.943549  1398.615327  Female
# ryoya1983                            3346.270178   302.151152    Male
# PLx2QMoA1Th9deXXbo7htq21CUPqEPPGuc   4555.551752   622.180444  Female
# ManjulasKitchen                       278.778218     2.800000  Female
# PLAzrgbu8gEMJe0ZOKPLRgEc-sp4cLmtz6   4143.215429  1098.848392    Male
# chefsteps                             624.451083   148.002717    Male
# UCekQr9znsk2vWxBo3YiLq2w             5000.420521  1276.420930    Male
#
# ...

# %%
### read in data
fileName3 = '../sentiment_analysis/textblob_data/gaming.txt'    
gaming = pd.read_csv(fileName3, sep=" ",header=None)
gaming.columns = ['Creator','Positive','Negative']
c = list(gaming['Creator'])
c = [i.split('.')[0] for i in c]
gaming['Creator'] = c
gaming.set_index('Creator', inplace=True)

#Normalize Scores
gaming['Negative'] = abs(gaming['Negative'])
gaming['Normalized Positive'] = gaming['Positive']/(gaming['Positive']+gaming['Negative'])*100
gaming['Normalized Negative'] = gaming['Negative']/(gaming['Positive']+gaming['Negative'])*100

# %%
gaming['Category'] = ['Gaming']*len(gaming)

# %%
gaming['Gender'] = ['Male']*len(gaming)

# %%
gaming
# Out:
#                        Positive     Negative  Normalized Positive  \
# Creator
# Willyrex             291.885122   182.640430            61.510939
# VanossGaming        2262.369613   198.494691            91.933944
# theRadBrad          3737.481331   940.985671            79.886880
# TheDiamondMinecart  3326.550023  1362.428214            70.944028
# MatthewPatrick13    6382.930572  2815.184687            69.393896
# SkyDoesMinecraft    3475.761340   631.079963            84.633447
# NinjasHyper         4056.051170  1131.656118            78.185814
# Matroix             3534.876497  1224.879920            74.265912
# Fernanfloo           305.406878   340.554167            47.279458
# vegetta777           491.690951   229.043465            68.220823
# JuegaGerman          439.321036   238.531257            64.810733
# jacksepticeye       4081.715808  1551.306641            72.460492
# outsidexbox         1951.692108  1208.884822            61.751134
# ...

# %%
frames = [cooking, gaming, influencers]

# %%
result = pd.concat(frames)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
result
# Out:
#                                        Category  Gender     Negative  \
# Creator
# ByronTalbott                            Cooking    Male   129.886387
# donalskehan                             Cooking    Male    78.765463
# PL2EC7F45DBD9D9B1A                      Cooking  Female  4053.419950
# LauraVitalesKitchen                     Cooking  Female   163.268098
# bgfilms                                 Cooking    Male  1664.841656
# cookingwithdog                          Cooking  Female  1398.615327
# ryoya1983                               Cooking    Male   302.151152
# PLx2QMoA1Th9deXXbo7htq21CUPqEPPGuc      Cooking  Female   622.180444
# ManjulasKitchen                         Cooking  Female     2.800000
# PLAzrgbu8gEMJe0ZOKPLRgEc-sp4cLmtz6      Cooking    Male  1098.848392
# chefsteps                               Cooking    Male   148.002717
# UCekQr9znsk2vWxBo3YiLq2w                Cooking    Male  1276.420930
# ...

# %%
g = result.groupby(by='Gender')

# %%
male = g.get_group('Male')

# %%
female = g.get_group('Female')

# %%
#vs category
d2 = result.groupby(by=['Category']).mean()

ax = d2.plot.bar(y=['Normalized Negative'],width = 0.8,rot=0)
ax.set_ylabel('% of Negative Comments')
ax.legend(loc='upper left', bbox_to_anchor=(1,1));
ax.get_legend().remove()

# %%
#vs category
d2 = result.groupby(by=['Gender']).mean()

ax = d2.plot.bar(y=['Normalized Negative'],width = 0.8,rot=0)
ax.set_ylabel('% of Negative Comments')
ax.legend(loc='upper left', bbox_to_anchor=(1,1));
ax.get_legend().remove()

# %%
d2
# Out:
#           Negative  Normalized Negative  Normalized Positive     Positive
# Gender
# Female  915.296252            12.796305            87.203695  5834.051989
# Male    836.275388            23.056364            76.943636  3202.971281

# %%
d2 = result.groupby(by=['Gender','Category']).mean()['Normalized Negative'].unstack().reset_index()
d2.set_index('Gender', inplace=True)

# %%
ax = d2.plot.bar(y=['Gaming', 'Cooking', 'Influencers'],width = 0.8,rot=0)
ax.legend(loc='best')
ax.set_ylabel('% of Negative Comments')
# Out:
# Text(0, 0.5, '% of Negative Comments')

# %%
result
# Out:
#                                        Category  Gender     Negative  \
# Creator
# ByronTalbott                            Cooking    Male   129.886387
# donalskehan                             Cooking    Male    78.765463
# PL2EC7F45DBD9D9B1A                      Cooking  Female  4053.419950
# LauraVitalesKitchen                     Cooking  Female   163.268098
# bgfilms                                 Cooking    Male  1664.841656
# cookingwithdog                          Cooking  Female  1398.615327
# ryoya1983                               Cooking    Male   302.151152
# PLx2QMoA1Th9deXXbo7htq21CUPqEPPGuc      Cooking  Female   622.180444
# ManjulasKitchen                         Cooking  Female     2.800000
# PLAzrgbu8gEMJe0ZOKPLRgEc-sp4cLmtz6      Cooking    Male  1098.848392
# chefsteps                               Cooking    Male   148.002717
# UCekQr9znsk2vWxBo3YiLq2w                Cooking    Male  1276.420930
# ...

# %%
subfilename = '../scraping/subscriber_count.txt'
subs = pd.read_csv(subfilename, sep=" ",header=None)

# %%
subs.columns = ['Creator', 'Subscribers', 'Category']

# %%
subs.set_index('Creator', inplace=True)

# %%
subs.drop(columns=['Category'], inplace=True)

# %%
subs
# Out:
#                                     Subscribers
# Creator
# bgfilms                                 4408943
# cookingwithdog                          1469723
# donalskehan                              811715
# PLx2QMoA1Th9deXXbo7htq21CUPqEPPGuc       504390
# PL2EC7F45DBD9D9B1A                      2457086
# ManjulasKitchen                          530909
# ryoya1983                               1954408
# UCekQr9znsk2vWxBo3YiLq2w                1755972
# ByronTalbott                            1435397
# PLAzrgbu8gEMJe0ZOKPLRgEc-sp4cLmtz6      5991238
# chefsteps                                885030
# LauraVitalesKitchen                     3439506
# VanossGaming                           24516631
# TheDiamondMinecart                     21596399
# jacksepticeye                          22081402
# NinjasHyper                            22076972
# MatthewPatrick13                       11645097
# AuthenticGames                         17088344
# ...

# %%
with_subs = pd.concat([result, subs], axis=1, sort=False)

# %%
#vs category
d2 = with_subs.groupby(by=['Category']).mean()
d2['Subscribers'] = d2['Subscribers']

ax = d2.plot.bar(y=['Subscribers'],width = 0.8,rot=0)
ax.set_ylabel('Subscribers (M)')
ax.get_legend().remove()

# %%
d2
# Out:
#           Negative  Normalized Negative  Normalized Positive     Positive  \
# Gender
# Female  915.296252            12.796305            87.203695  5834.051989
# Male    836.275388            23.056364            76.943636  3202.971281
#
#          Subscribers
# Gender
# Female  7.761680e+06
# Male    1.704825e+07

# %%
with_Msubs = with_subs
with_Msubs['Subscribers'] = with_Msubs['Subscribers']/1e6

# %%
with_Msubs['Subscribers Range'] = pd.cut(with_Msubs['Subscribers'], [0, 1.5, 5, 15, float('inf')])

# %%
with_Msubs
# Out:
#                                        Category  Gender     Negative  \
# ByronTalbott                            Cooking    Male   129.886387
# donalskehan                             Cooking    Male    78.765463
# PL2EC7F45DBD9D9B1A                      Cooking  Female  4053.419950
# LauraVitalesKitchen                     Cooking  Female   163.268098
# bgfilms                                 Cooking    Male  1664.841656
# cookingwithdog                          Cooking  Female  1398.615327
# ryoya1983                               Cooking    Male   302.151152
# PLx2QMoA1Th9deXXbo7htq21CUPqEPPGuc      Cooking  Female   622.180444
# ManjulasKitchen                         Cooking  Female     2.800000
# PLAzrgbu8gEMJe0ZOKPLRgEc-sp4cLmtz6      Cooking    Male  1098.848392
# chefsteps                               Cooking    Male   148.002717
# UCekQr9znsk2vWxBo3YiLq2w                Cooking    Male  1276.420930
# Willyrex                                 Gaming    Male   182.640430
# ...

# %%
#vs category
d2 = with_Msubs.groupby(by=['Subscribers Range']).mean()

ax = d2.plot.bar(y=['Normalized Negative'],width = 0.8,rot=0)
ax.set_xticklabels(ax.get_xticklabels());
ax.get_legend().remove()
ax.set_ylabel("% of Negative Comments")
ax.set_xlabel('Subscribers Range (M)')
# Out:
# Text(0.5, 0, 'Subscribers Range (M)')

# %%
d2 = with_subs.groupby(by=['Subscribers Range','Category']).mean()['Normalized Negative'].unstack().reset_index()
d2['Subscribers Range'] = d2['Subscribers Range']
d2.set_index('Subscribers Range', inplace=True)

# %%
ax = d2.plot.bar(y=['Gaming', 'Cooking', 'Influencers'],width = 0.8,rot=0)
ax.set_xticklabels(ax.get_xticklabels())
ax.legend(loc='best', bbox_to_anchor=(1,1))
ax.set_ylabel('% of Negative Comments')
ax.set_xlabel('Subscribers Range (M)')
# Out:
# Text(0.5, 0, 'Subscribers Range (M)')

# %%
#vs category
d2 = with_subs.groupby(by=['sub_slice']).sum()

# %%
d2
# Out:
#                              Negative  Normalized Negative  \
# sub_slice
# (0.0, 1500000.0]          2380.250338            66.438201
# (1500000.0, 5000000.0]   12022.021020           201.461967
# (5000000.0, 15000000.0]  11329.801024           233.068822
# (15000000.0, inf]        16193.671982           505.672151
#
#                          Normalized Positive      Positive  Subscribers
# sub_slice
# (0.0, 1500000.0]                  533.561799  13760.198093      5637164
# (1500000.0, 5000000.0]            898.538033  68531.986398     36405004
# (5000000.0, 15000000.0]           966.931178  48677.791119    125978409
# (15000000.0, inf]                1494.327849  57548.585660    555904865

# %%
d2 = with_subs.groupby(by=['sub_slice','Category']).mean()['Normalized Negative'].unstack().reset_index()
d2.set_index('sub_slice', inplace=True)

# %%
d2
# Out:
# Category                   Cooking     Gaming  Influencers
# sub_slice
# (0.0, 1500000.0]         11.073033        NaN          NaN
# (1500000.0, 5000000.0]   13.391531  38.248866    19.251090
# (5000000.0, 15000000.0]  20.962133  26.143709    15.361693
# (15000000.0, inf]              NaN  26.293615    24.457238

# %%
sl = {'0-1.5M':pd.Interval(0.0, 1500000.0), '1.5M-1.5M':pd.Interval(0.0, 1500000.0),
# Out:
# Interval(0.0, 1500000.0, closed='right')

# %%
d2 = cooking.groupby(by='Category').mean()
labels = 'Positive', 'Negative'
sizes = [d2['Normalized Positive'], d2['Normalized Negative']]
colors = ['lightskyblue', 'lightcoral']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes,labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False, startangle=90)
plt.title('Cooking')
plt.axis('equal')
plt.show()

# %%
d2 = gaming.groupby(by='Category').mean()
labels = 'Positive', 'Negative'
sizes = [d2['Normalized Positive'], d2['Normalized Negative']]
colors = ['lightskyblue', 'lightcoral']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes,labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False, startangle=90)
plt.title('Gaming')
plt.axis('equal')
plt.show()

# %%
d2 = influencers.groupby(by='Category').mean()
labels = 'Positive', 'Negative'
sizes = [d2['Normalized Positive'], d2['Normalized Negative']]
colors = ['lightskyblue', 'lightcoral']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes,labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False, startangle=90)
plt.title('Influencers')
plt.axis('equal')
plt.show()

# %%
d2 = with_subs.groupby(by=['Subscribers Range','Category']).mean()['Normalized Negative'].unstack().reset_index()
d2['Subscribers Range'] = d2['Subscribers Range']
d2.set_index('Subscribers Range', inplace=True)
ax = d2.plot.line(y=['Gaming', 'Cooking', 'Influencers'],rot=0)
ax.set_xticklabels(ax.get_xticklabels())
ax.legend(loc='best', bbox_to_anchor=(1,1))
ax.set_ylabel('% of Negative Comments')
ax.set_xlabel('Subscribers Range (M)')
ax = d2.plot.bar(y=['Cooking', 'Gaming', 'Influencers'],width = 0.8,rot=0)
ax.set_xticklabels(ax.get_xticklabels())
ax.legend(loc='best', bbox_to_anchor=(1,1))
ax.set_ylabel('% of Negative Comments')
ax.set_xlabel('Subscribers Range (M)')
# Out:
# Text(0.5, 0, 'Subscribers Range (M)')

# %%
d2
# Out:
# Category             Cooking     Gaming  Influencers
# Subscribers Range
# (0.0, 1.5]         11.073033        NaN          NaN
# (1.5, 5.0]         13.391531  38.248866    19.251090
# (5.0, 15.0]        20.962133  26.143709    15.361693
# (15.0, inf]              NaN  26.293615    24.457238

# %%
c = list(d2['Cooking'])
g = list(d2['Gaming'])
i = list(d2['Influencers'])

# %%
import numpy as np

# %%
ind = np.arange(4)*3

# %%
rects1 = plt.bar(ind, c, 0.8,label='Cooking')
rects2 = plt.bar(ind + 0.8, g, 0.8, label='Gaming')
rects3 = plt.bar(ind + 1.6, i, 0.8, label='Influencers')
c_line = plt.plot(ind, c, marker='o',color='#0000ff')
i_line = plt.plot(ind + 1.6, i, marker='o',color='#00ff00')
plt.ylabel('% of Negative Comments')
plt.xlabel('Subscribers')
plt.legend()
plt.xticks(ind-0.7, ('0', '1.5M', '5M', '15M', 'inf'))
plt.show()

# %%
indrects1 = plt.bar(ind, c, 0.8,label='Cooking')
rects2 = plt.bar(ind + 0.8, g, 0.8, label='Gaming')
rects3 = plt.bar(ind + 1.6, i, 0.8, label='Influencers')
g_line = plt.plot(ind + 0.8, g, marker='o',color='#ff0000')
plt.ylabel('% of Negative Comments')
plt.xlabel('Subscribers')
plt.legend()
plt.xticks(ind-0.7, ('0', '1.5M', '5M', '15M', 'inf'))
plt.show()

# %%
rects1 = plt.bar(ind, c, 0.8,label='Cooking')
rects2 = plt.bar(ind + 0.8, g, 0.8, label='Gaming')
rects3 = plt.bar(ind + 1.6, i, 0.8, label='Influencers')
plt.ylabel('% of Negative Comments')
plt.xlabel('Subscribers')
plt.legend()
plt.xticks(ind-0.7, ('0', '1.5M', '5M', '15M', 'inf'))
plt.show()

# %%
#vs category
d2 = with_Msubs.groupby(by=['Subscribers Range']).mean()

ax = d2.plot.bar(y=['Normalized Negative'],width = 0.8,rot=0)
ax.set_xticklabels(ax.get_xticklabels());
ax.get_legend().remove()
ax.set_ylabel("% of Negative Comments")
ax.set_xlabel('Subscribers Range (M)')
# Out:
# Text(0.5, 0, 'Subscribers Range (M)')

# %%
d2
# Out:
#                       Negative  Normalized Negative  Normalized Positive  \
# Subscribers Range
# (0.0, 1.5]          396.708390            11.073033            88.926967
# (1.5, 5.0]         1092.911002            18.314724            81.685276
# (5.0, 15.0]         944.150085            19.422402            80.577598
# (15.0, inf]         809.683599            25.283608            74.716392
#
#                       Positive  Subscribers
# Subscribers Range
# (0.0, 1.5]         2293.366349     0.939527
# (1.5, 5.0]         6230.180582     3.309546
# (5.0, 15.0]        4056.482593    10.498201
# (15.0, inf]        2877.429283    27.795243

# %%
neg = list(d2['Normalized Negative'])

# %%
rects1 = plt.bar(ind, neg, 2.4,label='')
plt.ylabel('% of Negative Comments')
plt.xlabel('Subscribers')
plt.xticks(ind-1.5, ('0', '1.5M', '5M', '15M', 'inf'))
plt.show()
