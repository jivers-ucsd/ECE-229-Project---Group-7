# %% [markdown]
# # For plotting graphs for news section of slides

# %%
import news_graph_functions as ngf

# %%
ngf.trump_comments_plot()

# %%
abc_pos_norm, abc_neg_norm = ngf.norm_polarities('.\\channel_sentiments\\ABC2.txt')
bbc_pos_norm, bbc_neg_norm = ngf.norm_polarities('.\\channel_sentiments\\BBC2.txt')
cbs_pos_norm, cbs_neg_norm = ngf.norm_polarities('.\\channel_sentiments\\CBS2.txt')
cnn_pos_norm, cnn_neg_norm = ngf.norm_polarities('.\\channel_sentiments\\CNN2.txt')
fox_pos_norm, fox_neg_norm = ngf.norm_polarities('.\\channel_sentiments\\FOX2.txt')
msnbc_pos_norm, msnbc_neg_norm = ngf.norm_polarities('.\\channel_sentiments\\MSNBC2.txt')

# %%
names = ['CBS','MSNBC','FOX','BBC','ABC','CNN']
pos_vals = [cbs_pos_norm,msnbc_pos_norm,fox_pos_norm,bbc_pos_norm,abc_pos_norm,cnn_pos_norm]
neg_vals = [cbs_neg_norm,msnbc_neg_norm,fox_neg_norm,bbc_neg_norm,abc_neg_norm,cnn_neg_norm]
ngf.bar(names,pos_vals,neg_vals)

# %% [markdown]
# ### CNN Wordclouds

# %%
cnn_wall = ngf.get_sentiment_trump('.\\data\\news\\CNN\\Wall')

# %%
ngf.posneg_wordcloud(cnn_wall[0])

# %%
ngf.posneg_wordcloud(cnn_wall[1])

# %% [markdown]
# ### FOX Wordclouds

# %%
fox_wall = ngf.get_sentiment_trump('.\\data\\news\\Fox\\Wall')

# %%
ngf.posneg_wordcloud(fox_wall[0])

# %%
ngf.posneg_wordcloud(fox_wall[1])

# %% [markdown]
# ### BBC Wordclouds

# %%
bbc_wall = ngf.get_sentiment_trump('.\\data\\news\\BBC\\Wall')

# %%
ngf.posneg_wordcloud(bbc_wall[0])

# %%
ngf.posneg_wordcloud(bbc_wall[1])
